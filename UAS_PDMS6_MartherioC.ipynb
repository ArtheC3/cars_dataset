# %%
import numpy as np
import pandas as pd

path = '/content/cars_dataset.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
# 5    A1  2016  13900    Automatic    32260   Petrol   30.0  58.9         1.4
# 6    A6  2016  13250    Automatic    76788   Diesel   30.0  61.4         2.0
# 7    A4  2016  11750       Manual    75185   Diesel   20.0  70.6         2.0
# 8    A3  2015  10200       Manual    46112   Petrol   20.0  60.1         1.4
# 9    A1  2016  12000       Manual    22451   Petrol   30.0  55.4         1.4
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi
# 5  audi
# 6  audi
# 7  audi
# 8  audi
# 9  audi

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax             float64
# mpg             float64
# engineSize      float64
# Make             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72435 entries, 0 to 72434
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         72435 non-null  object
#  1   year          72435 non-null  int64
#  2   price         72435 non-null  int64
#  3   transmission  72435 non-null  object
#  4   mileage       72435 non-null  int64
#  5   fuelType      72435 non-null  object
#  6   tax           72435 non-null  float64
#  7   mpg           72435 non-null  float64
#  8   engineSize    72435 non-null  float64
#  9   Make          72435 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.5+ MB

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax             float64
# mpg             float64
# engineSize      float64
# Make             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
df
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3           A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4           A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431      I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72432      I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %%
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
df['tax'].fillna(df['tax'].mean(), inplace=True)
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72435 entries, 0 to 72434
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         72435 non-null  object
#  1   year          72435 non-null  int64
#  2   price         72435 non-null  int64
#  3   transmission  72435 non-null  object
#  4   mileage       72435 non-null  int64
#  5   fuelType      72435 non-null  object
#  6   tax           72435 non-null  float64
#  7   mpg           72435 non-null  float64
#  8   engineSize    72435 non-null  float64
#  9   Make          72435 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.5+ MB

# %%
df['tax'].fillna(df['tax'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
df['Year'] = pd.to_datetime(df['year'], format='%Y')
df['Year'] = df['Year'].dt.year
df = df.drop("year", axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df["transmission"] = label_encoder.fit_transform(df["transmission"])
df["fuelType"] = label_encoder.fit_transform(df["fuelType"])
df["Make"] = label_encoder.fit_transform(df["Make"])

# %%
modelDummies = pd.get_dummies(df["model"], prefix="model")
df = pd.concat([df, modelDummies], axis=1)
df = df.drop("model", axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numerical_cols = ['price', 'mileage', 'tax', 'mpg', 'engineSize', 'Year']
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Antar Kolom')
plt.show()

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %%
X = df.drop("Make", axis=1)
y = df["Make"]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X, y = smote.fit_resample(X, y)

# %%
unique_classes, class_counts = np.unique(y, return_counts=True)
plt.figure(figsize=(8, 6))
plt.bar(unique_classes, class_counts, color='skyblue')
plt.title('Bar Chart dari Data y')
plt.xlabel('Kelas')
plt.ylabel('Frekuensi')
plt.xticks(unique_classes)
plt.show()

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

def xgboost_model(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    xgb_model = xgb.XGBClassifier()
    xgb_model.fit(X_train, y_train)
    y_pred = xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    print('Classification Report:')
    print(classification_report(y_test, y_pred))
    evaluation_results = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }
    return evaluation_results

evaluation_results = xgboost_model(X, y)
print("Accuracy:", evaluation_results['accuracy'])
print("Precision:", evaluation_results['precision'])
print("Recall:", evaluation_results['recall'])
print("F1-score:", evaluation_results['f1_score'])
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3669
#            1       1.00      1.00      1.00      3604
#            2       1.00      1.00      1.00      3557
#            3       1.00      1.00      1.00      3588
#            4       1.00      1.00      1.00      3626
#            5       1.00      1.00      1.00      3559
#            6       1.00      1.00      1.00      3547
#
#     accuracy                           1.00     25150
#    macro avg       1.00      1.00      1.00     25150
# weighted avg       1.00      1.00      1.00     25150
#
# Accuracy: 0.9999602385685885
# Precision: 0.999960249402766
# Recall: 0.9999602385685885
# F1-score: 0.9999602385066705

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

def svr_model(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    svr_model = SVR(kernel='rbf')  # Menggunakan kernel RBF
    svr_model.fit(X_train, y_train)
    y_pred = svr_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Visualisasi hasil
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
    plt.title('SVR Predictions vs Actual')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.grid(True)
    plt.show()

    print('Mean Squared Error:', mse)
    print('R-squared:', r2)

    evaluation_results = {
        'mse': mse,
        'r2_score': r2
    }
    return evaluation_results

evaluation_results = svr_model(X, y)
print("Mean Squared Error:", evaluation_results['mse'])
print("R-squared:", evaluation_results['r2_score'])
# Out:
# Mean Squared Error: 0.01066318783236216
# R-squared: 0.9973387806822422
# Mean Squared Error: 0.01066318783236216
# R-squared: 0.9973387806822422

# %%
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb

def xgboost_regressor(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    xgb_model = xgb.XGBRegressor()  # Menggunakan XGBRegressor untuk regresi
    xgb_model.fit(X_train, y_train)
    y_pred = xgb_model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Visualisasi hasil
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
    plt.title('XGBoost Regressor Predictions vs Actual')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.grid(True)
    plt.show()

    print('Mean Squared Error:', mse)
    print('R-squared:', r2)

    evaluation_results = {
        'mse': mse,
        'r2_score': r2
    }
    return evaluation_results

evaluation_results = xgboost_regressor(X, y)
print("Mean Squared Error:", evaluation_results['mse'])
print("R-squared:", evaluation_results['r2_score'])
# Out:
# Mean Squared Error: 0.024338968797002376
# R-squared: 0.9939257063689427
# Mean Squared Error: 0.024338968797002376
# R-squared: 0.9939257063689427

# %%
from sklearn.preprocessing import LabelEncoder

# Encode target variable if it's categorical
label_encoder = LabelEncoder()
df['Make'] = label_encoder.fit_transform(df['Make'])
y = df['Make']

# %%
# Memastikan X dan y untuk SVR
X_svr = df.drop("price", axis=1)
y_svr = df["price"]

# Fungsi percobaan SVR
def run_svr_experiment(X, y, n_trials=30, test_size=0.2, random_state=42):
    results = {'mse': [], 'r2_score': []}

    for i in range(n_trials):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state + i)
        svr_model = SVR(kernel='rbf')
        svr_model.fit(X_train, y_train)
        y_pred = svr_model.predict(X_test)

        results['mse'].append(mean_squared_error(y_test, y_pred))
        results['r2_score'].append(r2_score(y_test, y_pred))

    for metric in results:
        results[metric] = np.array(results[metric])

    avg_results = {metric: np.mean(results[metric]) for metric in results}
    return results, avg_results

svr_results, svr_avg_results = run_svr_experiment(X_svr, y_svr)
print("SVR Average Results:", svr_avg_results)
# Out:
# SVR Average Results: {'mse': 0.0035058228064787484, 'r2_score': 0.15803673869071813}

# %%
# Memastikan X dan y untuk Random Forest
X_rf = df.drop("Make", axis=1)
y_rf = df["Make"]

# Fungsi percobaan Random Forest
def run_rf_experiment(X, y, n_trials=30, test_size=0.2, random_state=42):
    results = {'accuracy': [], 'precision': [], 'recall': [], 'f1_score': []}

    for i in range(n_trials):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state + i)
        rf_model = RandomForestClassifier()
        rf_model.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)

        results['accuracy'].append(accuracy_score(y_test, y_pred))
        results['precision'].append(precision_score(y_test, y_pred, average='weighted'))
        results['recall'].append(recall_score(y_test, y_pred, average='weighted'))
        results['f1_score'].append(f1_score(y_test, y_pred, average='weighted'))

    for metric in results:
        results[metric] = np.array(results[metric])

    avg_results = {metric: np.mean(results[metric]) for metric in results}
    return results, avg_results

rf_results, rf_avg_results = run_rf_experiment(X_rf, y_rf)
print("Random Forest Average Results:", rf_avg_results)sss
# Out:
# Random Forest Average Results: {'accuracy': 0.9996479602402153, 'precision': 0.9996482427760985, 'recall': 0.9996479602402153, 'f1_score': 0.9996479491244641}

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

def xgboost_model(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    xgb_model = xgb.XGBClassifier()
    xgb_model.fit(X_train, y_train)
    y_pred = xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    print('Classification Report:')
    print(classification_report(y_test, y_pred))
    evaluation_results = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }
    return evaluation_results

evaluation_results = xgboost_model(X, y)
print("Accuracy:", evaluation_results['accuracy'])
print("Precision:", evaluation_results['precision'])
print("Recall:", evaluation_results['recall'])
print("F1-score:", evaluation_results['f1_score'])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

def random_forest_classifier(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    rf_model = RandomForestClassifier()
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Random Forest Classifier - Confusion Matrix')
    plt.show()

    print('Classification Report:')
    print(classification_report(y_test, y_pred))

    evaluation_results = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }
    return evaluation_results

rf_results = random_forest_classifier(X, y)
print("Random Forest Classifier - Accuracy:", rf_results['accuracy'])
print("Random Forest Classifier - Precision:", rf_results['precision'])
print("Random Forest Classifier - Recall:", rf_results['recall'])
print("Random Forest Classifier - F1-score:", rf_results['f1_score'])

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

def svr_regression(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    svr_model = SVR(kernel='rbf')  # Menggunakan kernel RBF
    svr_model.fit(X_train, y_train)
    y_pred = svr_model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Visualisasi hasil
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
    plt.title('SVR Predictions vs Actual')
    plt.xlabel('Actual Prices')
    plt.ylabel('Predicted Prices')
    plt.grid(True)
    plt.show()

    print('Mean Squared Error:', mse)
    print('R-squared:', r2)

    evaluation_results = {
        'mse': mse,
        'r2_score': r2
    }
    return evaluation_results

svr_results = svr_regression(X, y)
print("SVR - Mean Squared Error:", svr_results['mse'])
print("SVR - R-squared:", svr_results['r2_score'])
